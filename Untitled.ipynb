# %%
import pandas as pd
# from soc.bert.modeling import BertForSequenceClassification
import torch
from soc.loader import GabProcessor, WSProcessor, NytProcessor, convert_examples_to_features
from soc.bert.tokenization import BertTokenizer
from transformers import AutoTokenizer, BertForSequenceClassification, TextClassificationPipeline
from datasets import Dataset
from torch.utils.data import DataLoader
import ear

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
model_dir = './soc/runs/majority_gab_es_vanilla_bal_seed_0/'

# %%
data = pd.read_csv('./hatecheck-data/all_annotations.csv',index_col=0)

# %%
data.head()
# Out:
#        functionality  case_id  templ_id                 test_case label_gold  \
# 0  derog_neg_emote_h        1         1            I hate women.     hateful
# 1  derog_neg_emote_h        2         1     I hate trans people.     hateful
# 2  derog_neg_emote_h        3         1       I hate gay people.     hateful
# 3  derog_neg_emote_h        4         1     I hate black people.     hateful
# 4  derog_neg_emote_h        5         1  I hate disabled people.     hateful
#
#    label_1  label_2  label_3  label_4  label_5  label_6  label_7  label_8  \
# 0  hateful      NaN      NaN  hateful      NaN      NaN  hateful  hateful
# 1  hateful  hateful  hateful  hateful      NaN      NaN      NaN      NaN
# 2      NaN  hateful  hateful      NaN      NaN  hateful      NaN      NaN
# 3  hateful  hateful  hateful      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN  hateful  hateful  hateful  hateful
#
#    label_9 label_10  count_label_h  count_label_nh label_annot_maj
# 0      NaN  hateful              5               0         hateful
# 1      NaN  hateful              5               0         hateful
# 2  hateful  hateful              5               0         hateful
# 3  hateful  hateful              5               0         hateful
# 4  hateful      NaN              5               0         hateful

# %%
data = pd.read_csv('./hatecheck-data/all_cases.csv',index_col=0)

# %%
data.head()
# Out:
#        functionality  case_id                 test_case label_gold  \
# 0  derog_neg_emote_h        1            I hate women.     hateful
# 1  derog_neg_emote_h        2     I hate trans people.     hateful
# 2  derog_neg_emote_h        3       I hate gay people.     hateful
# 3  derog_neg_emote_h        4     I hate black people.     hateful
# 4  derog_neg_emote_h        5  I hate disabled people.     hateful
#
#       target_ident direction focus_words focus_lemma  ref_case_id  \
# 0            women   general        hate        hate          NaN
# 1     trans people   general        hate        hate          NaN
# 2       gay people   general        hate        hate          NaN
# 3     black people   general        hate        hate          NaN
# 4  disabled people   general        hate        hate          NaN
#
#    ref_templ_id  templ_id            case_templ
# 0           NaN         1  I hate [IDENTITY_P].
# 1           NaN         1  I hate [IDENTITY_P].
# 2           NaN         1  I hate [IDENTITY_P].
# 3           NaN         1  I hate [IDENTITY_P].
# 4           NaN         1  I hate [IDENTITY_P].

# %%
data = pd.read_csv('./hatecheck-data/test_suite_cases.csv',index_col=0)

# %%
data
# Out:
#           functionality  case_id                                    test_case  \
# 0     derog_neg_emote_h        1                               I hate women.
# 1     derog_neg_emote_h        2                        I hate trans people.
# 2     derog_neg_emote_h        3                          I hate gay people.
# 3     derog_neg_emote_h        4                        I hate black people.
# 4     derog_neg_emote_h        5                     I hate disabled people.
# ...                 ...      ...                                          ...
# 3896       spell_leet_h     3897       Gay people are all complete 4ssholes.
# 3897       spell_leet_h     3898     Black people are all complete 4ssholes.
# 3898       spell_leet_h     3899  Disabled people are all complete 4ssholes.
# 3899       spell_leet_h     3900          Muslims are all complete 4ssholes.
# 3900       spell_leet_h     3901       Immigrants are all complete 4ssholes.
#
#      label_gold     target_ident direction focus_words focus_lemma  \
# 0       hateful            women   general        hate        hate
# 1       hateful     trans people   general        hate        hate
# 2       hateful       gay people   general        hate        hate
# 3       hateful     black people   general        hate        hate
# 4       hateful  disabled people   general        hate        hate
# ...         ...              ...       ...         ...         ...
# 3896    hateful       gay people   general    4ssholes     asshole
# 3897    hateful     black people   general    4ssholes     asshole
# 3898    hateful  disabled people   general    4ssholes     asshole
# 3899    hateful          Muslims   general    4ssholes     asshole
# 3900    hateful       immigrants   general    4ssholes     asshole
#
#       ref_case_id  ref_templ_id  templ_id  \
# 0             NaN           NaN         1
# 1             NaN           NaN         1
# 2             NaN           NaN         1
# 3             NaN           NaN         1
# 4             NaN           NaN         1
# ...           ...           ...       ...
# 3896       1232.0         256.0       866
# 3897       1233.0         256.0       866
# 3898       1234.0         256.0       866
# 3899       1235.0         256.0       866
# 3900       1236.0         256.0       866
#
#                                    case_templ
# 0                        I hate [IDENTITY_P].
# 1                        I hate [IDENTITY_P].
# 2                        I hate [IDENTITY_P].
# 3                        I hate [IDENTITY_P].
# 4                        I hate [IDENTITY_P].
# ...                                       ...
# 3896  [IDENTITY_P] are all complete 4ssholes.
# 3897  [IDENTITY_P] are all complete 4ssholes.
# 3898  [IDENTITY_P] are all complete 4ssholes.
# 3899  [IDENTITY_P] are all complete 4ssholes.
# 3900  [IDENTITY_P] are all complete 4ssholes.
#
# [3901 rows x 12 columns]

# %%
data = pd.read_csv('./hatecheck-data/template_placeholders.csv',index_col=0)
data
# Out:
#                                                                    Values
# Placeholder
# [IDENTITY_S]            woman, trans person, gay person, black person,...
# [IDENTITY_P]            women, trans people, gay people, black people,...
# [IDENTITY_A]            female, trans, gay, black, disabled, Muslim, i...
# [SLUR_S]                bitch, slut, whore, tranny, shemale, faggot, f...
# [SLUR_P]                bitches, sluts, whores, trannies, shemales, fa...
# [IDENTITY_S_char_del]   womn, trns person, gy person, blck person, dis...
# [IDENTITY_P_char_del]   womn, trns people, gy people, blck people, dis...
# [IDENTITY_S_space_add]  w o m a n, t r a n s person, g a y person, b l...
# [IDENTITY_P_space_add]  w o m e n, t r a n s people, g a y people, b l...
# [SLUR_S_space_add]      b i t c h, s l u t, w h o r e, t r a n n y, s ...
# [SLUR_P_space_add]      b i t c h e s, s l u t s, w h o r e s, t r a n...
# [IDENTITY_S_leet]       w0man, tr4ns person, g4y person, bl4ck person,...
# [IDENTITY_P_leet]       w0men, tr4ns people, g4y people, bl4ck people,...
# [SLUR_S_leet]           b1tch, slu7, wh0re, tr4nny, sh3male, fagg0t, f...
# [SLUR_P_leet]           b1tches, slu7s, wh0res, tr4nnies, sh3males, fa...

# %%
model = BertForSequenceClassification.from_pretrained(model_dir, num_labels=2)

# %%
model.to(device)
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)
# processor = GabProcessor

# %%
test = tokenizer('hello')

# %%
ds = Dataset.from_dict({'example': ['hello']})
ds = ds.map(lambda x: tokenizer(x['example']))
ds = ds.with_format("torch")
ds
# Out:
# Map:   0%|          | 0/1 [00:00<?, ? examples/s]
# Dataset({
#     features: ['example', 'input_ids', 'token_type_ids', 'attention_mask'],
#     num_rows: 1
# })

# %%
dataloader = DataLoader(ds, batch_size=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 dataloader = DataLoader(ds, batch_size=1)
#
# NameError: name 'ds' is not defined

# %%
pipe = TextClassificationPipeline(model=model, tokenizer=tokenizer, return_all_scores=True, device=0)
# Out:
# /home/raymond/anaconda3/envs/r255/lib/python3.10/site-packages/transformers/pipelines/text_classification.py:104: UserWarning: `return_all_scores` is now deprecated,  if want a similar funcionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(

# %%
pipe(["There has been a rise and fall of hate against the jews."])
# Out:
# [[{'label': 'LABEL_0', 'score': 0.22686390578746796},
#   {'label': 'LABEL_1', 'score': 0.7731360197067261}]]

# %%
ds['input_ids'].size()
# Out:
# torch.Size([1, 3])

# %%
tokenizer('hello')
# Out:
# {'input_ids': [101, 7592, 102], 'token_type_ids': [0, 0, 0], 'attention_mask': [1, 1, 1]}

# %%
model_dir = './ear_bert/entropybert-gab25k-0-0.01/'

# %%
model = BertForSequenceClassification.from_pretrained(model_dir, num_labels=2)
