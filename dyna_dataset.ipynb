# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('./data/Dynamically-Generated-Hate-Speech-Dataset/Dynamically Generated Hate Dataset v0.2.3.csv', index_col=0)

# %%
data
# Out:
#           acl.id     X1                                               text  \
# 1           acl1      1                                dalits are lowlives
# 2          acl10      2             gay people are a burden to our society
# 3         acl100      3                              Arabs are not welcome
# 4        acl1000      4  I'm not saying we should actually eliminate he...
# 5       acl10000      5                       bananas are for black people
# ...          ...    ...                                                ...
# 117100   acl9974  41228                     Indian culture is so backwards
# 118100  acl11574   1752  Women don't want equality, they just want to b...
# 119100  acl13446   3832                                         fuck covid
# 1205    acl13457   3844                           This computer is garbage
# 121100  acl32095  24553                 The only good Muslim is a dead one
#
# ...

# %%
data_train, data_dev, data_test = data[data['split']=='train'], data[data['split']=='dev'], data[data['split']=='test']

# %%
data.split.value_counts()
# Out:
# train    32924
# test      4120
# dev       4100
# Name: split, dtype: int64

# %%
sns.countplot(data=data, x='round.base', hue='split')
# Out:
# <Axes: xlabel='round.base', ylabel='count'>

# %%
sns.countplot(data=data[data['label']=='hate'], x='target', hue='split')
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
data[(data['split']=='train')&(data['round.base']==1)]
# Out:
#          acl.id     X1                                               text  \
# 1          acl1      1                                dalits are lowlives
# 2         acl10      2             gay people are a burden to our society
# 3        acl100      3                              Arabs are not welcome
# 4       acl1000      4  I'm not saying we should actually eliminate he...
# 15      acl1001     15  It's such a rape culture with these immigrants...
# ...         ...    ...                                                ...
# 103100  acl8814  39940                        asians are good for nothing
# 104     acl8815  39941                  black people are good for nothing
# 105100  acl8856  39986               Women who don't want kids are freaks
# 1066    acl8862  39993                                      Men own women
# 107100  acl8894  40028                                Women are deceitful
#
#        label      type    target     level  split  round.base   annotator  \
# ...
